# %%
import numpy as np
import pandas as pd
import datetime

# %%
nvda = yf.Ticker("NVDA")

nvda_hist = nvda.history(start="2000-01-01", end=datetime.date.today())
nvda_hist.head(5)
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2000-01-03 00:00:00-05:00  0.090268  0.090984  0.084297  0.089431  300912000
# 2000-01-04 00:00:00-05:00  0.087879  0.088118  0.082625  0.087044  300480000
# 2000-01-05 00:00:00-05:00  0.084536  0.085969  0.082984  0.084178  188352000
# 2000-01-06 00:00:00-05:00  0.084178  0.084178  0.075462  0.078685  120480000
# 2000-01-07 00:00:00-05:00  0.078327  0.080835  0.077134  0.079999   71184000
#
#                            Dividends  Stock Splits
# Date
# 2000-01-03 00:00:00-05:00        0.0           0.0
# 2000-01-04 00:00:00-05:00        0.0           0.0
# 2000-01-05 00:00:00-05:00        0.0           0.0
# 2000-01-06 00:00:00-05:00        0.0           0.0
# 2000-01-07 00:00:00-05:00        0.0           0.0

# %%
nvda_hist.to_csv("nvda_historical_data.csv")
print("CSV file saved: nvda_historical_data.csv")
# Out:
# CSV file saved: nvda_historical_data.csv
